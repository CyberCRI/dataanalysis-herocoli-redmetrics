# %% [markdown]
# # French translation CSV exports

# %% [markdown]
# [Translation of all answers](#translation)
#
# [Assembly of all answers](#assembly)
#
# [Export](#export)
#
# [Deprecated: demographic and scientific 'correct' answers](#corrdemosci)

# %%
# %run "../Functions/0.1 GF English localization.ipynb"

# %% [markdown]
# ## Translation of all possible answers
# <a id=translation />

# %%
# Options that don't need translations are commented out
# The first translated element is the correct answer when applicable
# Options that are deprecated are listed last

interestTranslation = {
	"Pas du tout" : "Not at all",
	"Un peu" : "Slightly",
	"Moyennement" : "Moderately",
	"Beaucoup" : "A lot",
	"Enormément" : "Extremely",
	"Énormément" : "Extremely",
	}

everPlayedTranslation = {
    "Je viens d'y jouer pour la première fois" : "I just played for the first time",
    "J'y ai joué plusieurs fois récemment sur cet ordinateur" : "I played it multiple times recently on this computer",
    "J'y ai joué récemment sur un autre ordinateur" : "I played recently on an other computer",
    "J'y ai joué il y a un moment" : "I played it some time ago",
    "Non / pas encore" : "No / not yet",
    }

genderTranslation = {
	"Femme" : "Female",
	"Homme" : "Male",
	"Autre" : "Other",
	"Je ne souhaite pas le préciser" : "Prefer not to say",
    }

biologyStudyTranslation = {
	"Jamais, pas même au collège" : "Not even in middle school",
	"Jusqu'au brevet" : "Until the end of middle school",
	"Jusqu'au bac" : "Until the end of high school",
	"Jusqu'à la license" : "Until bachelor's degree",
	"Au moins jusqu'au master" : "At least until master's degree",
	}

frequencyTranslation = {
	"Pas du tout" : "Not at all",
	"Un peu" : "Rarely",
	"Moyennement" : "Moderately",
	"Beaucoup" : "A lot",
	"Enormément" : "Extremely",
	"Énormément" : "Extremely",
	}

heardAboutBioBricksTranslation = {
    "Non" : "No",
    "Oui, mais je ne sais pas exactement ce que c'est" : "Yes, but I don't exactly know what it means",
    "Oui, et je sais ce que c'est" : "Yes, and I know what it means",
	}

yesNoTranslation = {
	"Oui" : "Yes",
	"Non" : "No",
	}

enjoyedTheGameTranslation = {
    "Ne s'applique pas : pas encore joué" : "Not applicable: not played yet",
    "Pas du tout" : "Not at all",
    "Un peu" : "A bit",
    "Moyennement" : "Moderately",
    "Beaucoup" : "A lot",
    "Extrêmement" : "Extremely",
    }

Q16AnswersTranslation = {
	"Modifier l'ADN de la bactérie" : "Edit the DNA of the bacterium",
	"Ramasser des nanorobots" : "Gather nanobots",
	"Faire bouger la bactérie" : "Move the bacterium",
	"Diviser la bactérie" : "Divide the bacterium",
	"Je ne sais pas" : "I don't know",
	}

Q17AnswersTranslation = {
	"Des séquences d'ARN" : "RNA sequences",
	"Des acides aminés" : "Amino-acids",
	"Des protéines" : "Proteins",
	"Des séquences d'ADN" : "DNA sequences",
	"Je ne sais pas" : "I don't know",
	}

Q18AnswersTranslation = {
	"Ampicilline" : "Ampicillin",
	#"Arabinose"
	#"GFP"
	"Terminateur" : "Terminator",
	"Je ne sais pas" : "I don't know",
	}

BioBrickAnswersTranslation = {
	"Aucun de ces éléments" : "None of these",
	#	1	
	#	2	
	#	3	
	#	4	
	#	5	
	"Je ne sais pas" : "I don't know",
	}

DeviceAnswersTranslation = {
	"Les briques ne sont pas dans le bon ordre" : "The bricks are not well-ordered",
	"Elle produit la fluorescence verte" : "It generates green fluorescence",
	"Elle produit la fluorescence verte en présence d'inducteur arabinose" : "It generates green fluorescence in presence of arabinose inducer",
	"Elle permet de se déplacer plus vite" : "It makes it possible to move faster",
	"Elle permet de résister aux antibiotiques" : "It generates antibiotic resistance",
	"Je ne sais pas" : "I don't know",
	}

Q40AnswersTranslation = {
	"Sous lumière bleue, quand la construction GFP est équipée" : "Under blue light, when the GFP device is equipped",
	"Sous lumière bleue, tout le temps" : "Under blue light, all the time",
	"Devant les portes, quand la construction GFP est équipée" : "In front of the doors, when the GFP device is equipped",
	"Devant les portes, tout le temps" : "In front of the doors, all the time",
	"Je ne sais pas" : "I don't know",
	}

Q41AnswersTranslation = {
	"La bactérie devient lumineuse" : "The bacterium glows",
	"La bactérie meurt" : "The bacterium dies",
	"Les flagelles disparaissent l'un après l'autre, rapidement" : "Flagella quickly disappear one by one",
	"Rien" : "Nothing",
	"Je ne sais pas" : "I don't know",
	}

Q42AnswersTranslation = {
	"Elle produit de l'arabinose tout le temps." : "It produces arabinose all the time",
	"Elle n'est active que dans les nuages d'arabinose." : "It is active only in arabinose clouds",
	"Elle produit de plus en plus d'arabinose après avoir été induite, puisqu'elle s'induit elle-même." : "It produces more and more arabinose after being induced, because it induces itself",
	"Elle ne produit rien puisqu'elle s'induit elle-même" : "It produces nothing since it induces itself",
	"Je ne sais pas" : "I don't know",
	}

# %% [markdown]
# ## Assembly of all possible answers
# <a id=assembly />

# %%
questionsAnswersTranslationsFR = pd.Series(
    [
            
# Timestamp
        #'Timestamp', #01
            [],

# Basic engagement questions
        #'Are you interested in learning more about...Biology', #02
            interestTranslation,
        #'Are you interested in learning more about...Synthetic biology', #03
            interestTranslation,
        #'Are you interested in learning more about...Video games', #04
            interestTranslation,
        #'Are you interested in learning more about...Engineering', #05
            interestTranslation,

# Experience with Hero.Coli
        #'Have you ever played Hero.Coli?', #06
            everPlayedTranslation,

# Basic demographics questions
        #'How old are you?', #07
            [],
        #'What is your gender?', #08
            genderTranslation,
        #'Are you interested in video games?', #09
            interestTranslation,
        #'Are you interested in biology?', #10
            interestTranslation,
        #'How long have you studied biology?', #11
            biologyStudyTranslation,
        #'Do you play video games?', #12
            frequencyTranslation,

# Basic biology questions
        #'Have you ever heard about synthetic biology or BioBricks, outside of Hero.Coli?', #13
            heardAboutBioBricksTranslation,

# Basic engagement questions
        #'Do you volunteer to contribute to our study by answering 9 more questions? (5 min)', #14
            yesNoTranslation,
        #'Did you enjoy playing the game?', #15
            enjoyedTheGameTranslation,

# General mechanics of the game
        #'In order to modify the abilities of the bacterium, you have to...', #16
            Q16AnswersTranslation,
        #'What are BioBricks and devices?', #17
            Q17AnswersTranslation,
        #'Find the antibiotic:', #18
            Q18AnswersTranslation,

# BioBrick names and functions
        #'Plasmid is...', #19
            BioBrickAnswersTranslation,
        #'Represents the end of a device... TER', #20
            BioBrickAnswersTranslation,
        #'Promoter is...', #21
            BioBrickAnswersTranslation,
        #'Represents the ability given... CDS', #22
            BioBrickAnswersTranslation,
        #'Terminator is...', #23
            BioBrickAnswersTranslation,
        #'Codes a protein... CDS', #24
            BioBrickAnswersTranslation,
        #'RBS is...', #25
            BioBrickAnswersTranslation,
        #'Can represent GFP... CDS', #26
            BioBrickAnswersTranslation,
        #'Coding Sequence is...', #27
            BioBrickAnswersTranslation,
        #'Controls when the device is active... PR', #28
            BioBrickAnswersTranslation,
        #'Controls the level of expression, and thus how much the ability will be affected... RBS', #29
            BioBrickAnswersTranslation,
        #'Makes it possible to equip an additional device. PLASMID', #30
            BioBrickAnswersTranslation,
        #'Operator is... XXX', #31
            BioBrickAnswersTranslation,

# Device symbols
        #'What does this device do? RBS:PCONS:FLHDC:TER XXX', #32
            DeviceAnswersTranslation,
        #'What does this device do? PCONS:RBS:FLHDC:TER', #33
            DeviceAnswersTranslation,
        #'What does this device do? PBAD:RBS:GFP:TER', #34
            DeviceAnswersTranslation,
        #'What does this device do? PBAD:GFP:TBS:TER XXX', #35
            DeviceAnswersTranslation,
        #'What does this device do? GFP:RBS:PCONS:TER XXX', #36
            DeviceAnswersTranslation,
        #'What does this device do? PCONS:GFP:RBS:TER XXX', #37
            DeviceAnswersTranslation,
        #'What does this device do? AMPR:RBS:PCONS:TER XXX', #38
            DeviceAnswersTranslation,
        #'What does this device do? RBS:PCONS:AMPR:TER XXX', #39
            DeviceAnswersTranslation,

# Beyond the game
        #'When does green fluorescence happen?', #40
            Q40AnswersTranslation,
        #'What happens when you unequip the movement device?', #41
            Q41AnswersTranslation,
        #'Last question. Next page only contains remarks.Guess: you have crafted a functional device containing an arabinose-induced promoter and an arabinose Coding Sequence (CDS). What will happen?', #42
            Q42AnswersTranslation,

# Remarks
        #'You can write down remarks here.', #43
            [],

# Technical data
        #'userID', #44
            [],
        #'Language', #45
            [],
        #'Temporality' #46
            [],
            
        ], index = gformEN1522.columns
)
#questionsAnswersTranslationsFR
#questionsAnswersTranslationsFR.loc['Are you interested in video games?']['Beaucoup']

# %%
#questionsAnswersTranslationsFR

# %% [markdown]
# ## Export
# <a id=export />

# %%
#questionsAnswersTranslationsFR.to_csv(frTranslationsPath, encoding=csvEncoding)

# %% [markdown]
# ## Deprecated: demographic and scientific 'correct' answers
# <a id=corrdemosci />

# %%
#demographicAnswersFR
#correctAnswersFR

# %%
#demographicAnswersFR.to_csv(frDemographicAnswersPath, encoding=csvEncoding)
#correctAnswersFR.to_csv(frCorrectScientificAnswersPath, encoding=csvEncoding)
